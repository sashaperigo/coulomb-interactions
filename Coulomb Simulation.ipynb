# %%
from environment import Environment
# %matplotlib inline

# %%
environ = Environment()
environ.add_electron(1, 1, 0, 0)
environ.add_electron(0, 1, 0, 0)
environ.add_proton(1, 0, 0, 0)
environ.plot_charges(1)
# Out:
# [1e-06, 1.0000000006360099e-06, 9.999999980919704e-07, 9.999999923678816e-07, 9.999999821917237e-07, 9.999999662914766e-07, 9.999999433951204e-07, 9.999999122306344e-07, 9.999998715259977e-07, 9.999998200091888e-07, 9.99999756408185e-07, 9.999996794509635e-07, 9.99999587865499e-07, 9.999994803797655e-07, 9.99999355721735e-07]
# [1e-06, 1.0000000006360099e-06, 9.999999980919704e-07, 9.999999923678816e-07, 9.999999821917237e-07, 9.999999662914766e-07, 9.999999433951204e-07, 9.999999122306344e-07, 9.999998715259977e-07, 9.999998200091888e-07, 9.99999756408185e-07, 9.999996794509635e-07, 9.99999587865499e-07, 9.999994803797655e-07, 9.99999355721735e-07]
# ...
